# %% [markdown]
# # Reformat Training Data & Retrain Model
# This script aims to transform the training data that was generated from R to a python-friendly format.
# Transformations include:
# - remove dots from column names
# - change "percentile" to "%ile" that is used in the aggregated files
# - change driver_gene column name to "Gene of Interest"
#
# We will load the pre-imputed data such that we will find a python function to impute missing values that will be consisitant for the future. The model will be tuned and trained on this new data to compare to the previous version in 07_ml_randomForest.ipynb
#
# The model should be the one to be used on new cases.

# %%
import os
import pandas as pd
import numpy as np
from pathlib import Path
from imblearn.ensemble import BalancedRandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, roc_auc_score, roc_curve, accuracy_score
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer # experimental
from sklearn.model_selection import train_test_split, GridSearchCV
import matplotlib.pyplot as plt
import seaborn as sns
import joblib

# %% [markdown]
# Set project and output directories:

# %%
# Set the working directory
project_dir = Path("/Users/Jennie/Desktop/WashU/Rotation_labs/Griffith Lab/Neoantigen ML project")
os.chdir(project_dir)

# Define output directory
outdir = project_dir / "output_python" / "transform_training_data_model.ipynb"
os.makedirs(outdir, exist_ok=True)
print(f"Output directory created at: {outdir}")
# Out:
# Output directory created at: /Users/Jennie/Desktop/WashU/Rotation_labs/Griffith Lab/Neoantigen ML project/output_python/transform_training_data4python.ipynb

# %% [markdown]
# Load pre-imputed data from R

# %%
# load the pre-imputed data
pre_imputed_data = pd.read_excel(project_dir / "output" / "05_cleaning_imputation.Rmd" / "merged_df_ml2_replace.xlsx")
print(pre_imputed_data.head())
pre_imputed_data.shape
# Out:
#                               ID Evaluation  TSL  Pos  Prob.Pos  \
# 0     chr1-11833944-11833945-G-A     Accept    1  2.0         0
# 1   chr1-159440212-159440213-G-A    Pending    6  8.0         0
# 2  chr11-124038758-124038759-C-A    Pending    6  1.0         0
# 3    chr12-25245349-25245350-C-T     Accept    1  5.0         0
# 4    chr12-78177209-78177210-A-T     Reject    1  9.0         0
#
#    Num.Passing.Peptides  RNA.Expr  RNA.VAF  Allele.Expr  RNA.Depth  ...  \
# 0                     2    15.729    0.353        5.552      218.0  ...
# 1                    10     0.010    0.000        0.000        0.0  ...
# 2                     2     0.000    0.000        0.000        0.0  ...
# 3                     3    21.814    0.341        7.439      569.0  ...
# 4                     0     9.642    0.230        2.218      100.0  ...
#
#    SMM.MT.IC50.Score  SMM.WT.Percentile SMM.MT.Percentile  \
# 0         341.326494               46.0              15.0
# 1         124.322576                0.6               0.5
# 2         783.971004                2.5               3.6
# 3         155.704083                1.2               1.3
# 4         523.094315               33.0               4.9
#
#   SMMPMBEC.WT.IC50.Score  SMMPMBEC.MT.IC50.Score  SMMPMBEC.WT.Percentile  \
# 0            2408.074950              882.409144                    51.0
# 1             173.432307              151.053224                     0.6
# 2             540.791678              845.337237                     2.8
# 3             112.209596              148.603829                     1.0
# 4           12842.216879              510.082002                    32.0
#
#    SMMPMBEC.MT.Percentile  Prob.match  driver_gene    patient_id
# 0                    29.0          NO           NO  TWJF-5120-04
# 1                     0.6          NO           NO  TWJF-5120-04
# 2                     3.7          NO           NO  TWJF-5120-04
# 3                     1.3          NO          YES  TWJF-5120-04
# 4                     4.8          NO           NO  TWJF-5120-04
#
# [5 rows x 75 columns]
# (1324, 75)

# %% [markdown]
# Rename columns to remove ".", change "driver_gene" to "Gene of Interest", change "percentile" to "%ile".

# %%
# %% Edit column names and Evaluation values -------------------------------------------------------------------------------------------------------------
# Replace all "." with a space " "
pre_imputed_data.columns = pre_imputed_data.columns.str.replace(".", " ", regex=False)
# rename "driver_gene" to "Gene of Interest"
pre_imputed_data.rename(columns={"driver_gene": "Gene of Interest"}, inplace=True)
# Rename "percentile" to "%ile"
pre_imputed_data.rename(columns=lambda x: x.replace("percentile", "%ile"), inplace=True)

# Change "Pending" to "Reject"
#pre_imputed_data['Evaluation'] = pre_imputed_data['Evaluation'].replace('Pending', 'Reject')
# Drop "Review" from the dataset
#
print(pre_imputed_data.columns.tolist())
# Save a copy of pre_imputed_data in the output directory
pre_imputed_data.to_csv(outdir / "pre_imputed_data.csv", index=False)
print(f"Pre-imputed data saved to: {outdir / 'pre_imputed_data.csv'}")
# Out:
# ['ID', 'Evaluation', 'TSL', 'Pos', 'Prob Pos', 'Num Passing Peptides', 'RNA Expr', 'RNA VAF', 'Allele Expr', 'RNA Depth', 'DNA VAF', 'Ref Match', 'Biotype', 'Variant Type', 'Peptide Length', 'Best MT IC50 Score', 'Corresponding WT IC50 Score', 'Corresponding Fold Change', 'Best MT Percentile', 'Corresponding WT Percentile', 'Median Fold Change', 'cysteine_count', 'IC50 MT class1', 'IC50 WT class1', 'IC50 MT class2', 'IC50 WT class2', '%ile MT class1', '%ile WT class1', '%ile MT class2', '%ile WT class2', 'MHCflurryEL Processing WT Score', 'MHCflurryEL Processing MT Score', 'MHCflurryEL Presentation WT Score', 'MHCflurryEL Presentation MT Score', 'MHCflurryEL Presentation WT Percentile', 'MHCflurryEL Presentation MT Percentile', 'MHCflurry WT IC50 Score', 'MHCflurry MT IC50 Score', 'MHCflurry WT Percentile', 'MHCflurry MT Percentile', 'MHCnuggetsI WT IC50 Score', 'MHCnuggetsI MT IC50 Score', 'MHCnuggetsI WT Percentile', 'MHCnuggetsI MT Percentile', 'NetMHC WT IC50 Score', 'NetMHC MT IC50 Score', 'NetMHC WT Percentile', 'NetMHC MT Percentile', 'NetMHCcons WT IC50 Score', 'NetMHCcons MT IC50 Score', 'NetMHCcons WT Percentile', 'NetMHCcons MT Percentile', 'NetMHCpan WT IC50 Score', 'NetMHCpan MT IC50 Score', 'NetMHCpan WT Percentile', 'NetMHCpan MT Percentile', 'NetMHCpanEL WT IC50 Score', 'NetMHCpanEL MT IC50 Score', 'NetMHCpanEL WT Percentile', 'NetMHCpanEL MT Percentile', 'PickPocket WT IC50 Score', 'PickPocket MT IC50 Score', 'PickPocket WT Percentile', 'PickPocket MT Percentile', 'SMM WT IC50 Score', 'SMM MT IC50 Score', 'SMM WT Percentile', 'SMM MT Percentile', 'SMMPMBEC WT IC50 Score', 'SMMPMBEC MT IC50 Score', 'SMMPMBEC WT Percentile', 'SMMPMBEC MT Percentile', 'Prob match', 'Gene of Interest', 'patient_id']
# Pre-imputed data saved to: /Users/Jennie/Desktop/WashU/Rotation_labs/Griffith Lab/Neoantigen ML project/output_python/transform_training_data4python.ipynb/pre_imputed_data.csv

# %% [markdown]
# Encode categorical variables

# %%
categorical_columns = pre_imputed_data.select_dtypes(include=['category', 'object']).columns.drop(['Evaluation', 'ID', 'patient_id'])
print("Categorical columns:", categorical_columns)

# Step 2: Label encode categorical columns
label_encoders = {}
for col in categorical_columns:
    le = LabelEncoder()
    pre_imputed_data[col] = le.fit_transform(pre_imputed_data[col])
    label_encoders[col] = le  # Store the encoder for future use
# Out:
# Categorical columns: Index(['Biotype', 'Variant Type', 'Prob match', 'Gene of Interest'], dtype='object')

# %% [markdown]
# ## Impute missing values
#
# NOTE: the chunk below was commented out since IterativeImputer is considered experimental. For reproducibility purposes, I am reading in the previously imputed data instead of imputing it again.

# %% [raw]
# # %% Impute missing values------------------------------------------------------------------------------------
# # Exclude columns from imputation
# exclude_columns = ["ID", "patient_id", "Evaluation"]
# columns_to_impute = pre_imputed_data.columns.difference(exclude_columns)
#
# # Separate the columns to exclude
# excluded_data = pre_imputed_data[exclude_columns]
# data_to_impute = pre_imputed_data[columns_to_impute]
#
# # Initialize the IterativeImputer
# imputer = IterativeImputer(random_state=918)
#
# # Impute missing values only in the selected columns
# imputed_data = imputer.fit_transform(data_to_impute)
#
# # Convert the imputed data back to a DataFrame
# imputed_data = pd.DataFrame(imputed_data, columns=columns_to_impute)
#
# # Combine the excluded columns back with the imputed data
# post_imputed_data = pd.concat([excluded_data.reset_index(drop=True), imputed_data.reset_index(drop=True)], axis=1)
#
# # save data
# post_imputed_data.to_csv(outdir / "df_imputed_python.csv", index=False)

# %% [markdown]
# Remove "Review"
# Change "Pending" to "Reject"

# %%
post_imputed_data = pd.read_csv(outdir / "df_imputed_python.csv")

# %%
# Filter out "Review" and replace "Pending" with "Reject"
post_imputed_data = post_imputed_data[post_imputed_data['Evaluation'] != 'Review']  # Remove rows with "Review"
post_imputed_data['Evaluation'] = post_imputed_data['Evaluation'].replace('Pending', 'Reject')  # Replace "Pending" with "Reject"

# Encode "Accept" as 1 and "Reject" as 0
post_imputed_data['Evaluation'] = post_imputed_data['Evaluation'].map({'Accept': 1, 'Reject': 0})

#Check the mapping
label_encoders['Evaluation'] = {'Accept': 1, 'Reject': 0}
print("Mapping for categorical variables:")
for col, le in label_encoders.items():
    print(f"Mapping for {col}:")
    if isinstance(le, LabelEncoder):
        for class_index, class_label in enumerate(le.classes_):
            print(f"  {class_label} -> {class_index}")
    elif isinstance(le, dict):
        for class_label, class_index in le.items():
            print(f"  {class_label} -> {class_index}")
# Out:
# Mapping for categorical variables:
# Mapping for Biotype:
#   IG_V_gene -> 0
#   nonsense_mediated_decay -> 1
#   protein_coding -> 2
# Mapping for Variant Type:
#   FS -> 0
#   inframe_del -> 1
#   inframe_ins -> 2
#   missense -> 3
# Mapping for Prob match:
#   NO -> 0
#   YES -> 1
#   nan -> 2
# Mapping for Gene of Interest:
#   NO -> 0
#   YES -> 1
# Mapping for Evaluation:
#   Accept -> 1
#   Reject -> 0

# %% [markdown]
# ## Split data into training and testing

# %%
# Split the data into 75% training and 25% testing sets
train_data, test_data = train_test_split(post_imputed_data, test_size=0.25, random_state=918)

# Save the training and testing sets if needed
train_data.to_csv(outdir / "train_data_python.csv", index=False)
test_data.to_csv(outdir / "test_data_python.csv", index=False)

# Separate features and target for training data
X_train = train_data.drop(columns=['Evaluation'])
y_train = train_data['Evaluation']

# Separate features and target for testing data
X_test = test_data.drop(columns=['Evaluation'])
y_test = test_data['Evaluation']

# Drop "ID" and "patient_id" columns from training and testing datasets
X_train = X_train.drop(columns=['ID', 'patient_id'])
X_test = X_test.drop(columns=['ID', 'patient_id'])

print(f"X_train shape: {X_train.shape}, X_test shape: {X_test.shape}")
# Out:
# X_train shape: (927, 72), X_test shape: (310, 72)

# %% [markdown]
# # RF with down-sampling

# %% [markdown]
# ## Tune random forest

# %% [raw]
# # Get the total number of CPU cores
# #total_cores = os.cpu_count()
#
# # Use half of the available cores
# #n_jobs_to_use = max(1, total_cores // 2)  # Ensure at least 1 core is used
# #print(f"Total cores available: {total_cores}, using {n_jobs_to_use} cores.")
#
# rf = BalancedRandomForestClassifier(
#     oob_score=True,
#     n_estimators=100, # Default number of trees for the model during initialization, but it gets overridden in GridSearchCV
#     random_state=918, # Set random seed for reproducibility
#     n_jobs=-1, # use half of the cores (to use all available cores set n_jobs=-1)
#     replacement=True,
#     bootstrap=True  # Set bootstrap=True for OOB estimation
# )
#
# # Define search space for max_features (mtry) and n_estimators (ntree)
# param_grid = {
#     'max_features': list(range(1, 72)),  # mtry from 1 to 72 since there are 72 features in total
#     'n_estimators': list(range(1, 5001, 50))  # ntree from 1 to 5000 with 50 interval
# }
#
# # Grid search with OOB scoring (not used directly, but available after fit)
# grid_search = GridSearchCV(
#     estimator=rf,               # The base model to tune (BalancedRandomForestClassifier in this case)
#     param_grid=param_grid,      # Dictionary of hyperparameters to search over
#     scoring='roc_auc',         # Metric to evaluate model performance (could choose "accuracy, "f1", "roc_auc", etc.)
#     cv=3,                       # Number of cross-validation folds (3-fold cross-validation)
#     n_jobs=-1,       # Number of CPU cores to use for parallel processing
#     verbose=2                   # Level of verbosity (2 provides detailed output during the search)
# )
#
#
# # Use grid search to fit the model with encoded data, find the best parameters
# grid_search.fit(X_train, y_train)
#
# best_params = grid_search.best_params_
# best_mtry = best_params['max_features']
# best_ntree = best_params['n_estimators']
# print(f"Best max_features (mtry): {best_mtry}")
# print(f"Best n_estimators (ntree): {best_ntree}")
# print(f"Best parameters: {best_params}")
#
# # Save the best mtry and ntree
# joblib.dump(best_mtry, outdir / "best_mtry_rf.pkl")
# joblib.dump(best_ntree, outdir / "best_ntree_rf.pkl")

# %% [raw]
# # Save the GridSearchCV results to a CSV file
# results_df = pd.DataFrame(grid_search.cv_results_)
# results_df.to_csv(outdir / "grid_search_results.csv", index=False)
# print("GridSearchCV results saved to grid_search_results.csv")
#
# # Save the best parameters to a text file
# with open(outdir / "best_params.txt", "w") as f:
#     f.write(f"Best max_features (mtry): {best_mtry}\n")
#     f.write(f"Best n_estimators (ntree): {best_ntree}\n")
#     f.write(f"Best parameters: {best_params}\n")
# print("Best parameters saved to best_params.txt")
#
# # Save the trained model
# joblib.dump(rf, outdir / "rf_tune_model.pkl")

# %% [markdown]
# ## Train

# %%
best_mtry = joblib.load(outdir / "best_mtry_rf.pkl")
best_ntree = joblib.load(outdir / "best_ntree_rf.pkl")
# Train the final Random Forest model
rf_ds = BalancedRandomForestClassifier(
    n_estimators=best_ntree,
    max_features=best_mtry,
    oob_score=True, 
    random_state=918,
    n_jobs=-1,
    replacement=True,
    bootstrap=True  # Set bootstrap=True for OOB estimation
)
rf_ds.fit(X_train, y_train)

# Save the trained model
joblib.dump(rf_ds, outdir / "rf_downsample_model.pkl")
joblib.dump(rf_ds, project_dir / "output_python" / "model_artifacts" / "rf_downsample_model.pkl")
# Out:
# ['/Users/Jennie/Desktop/WashU/Rotation_labs/Griffith Lab/Neoantigen ML project/output_python/transform_training_data4python.ipynb/rf_downsample_model.pkl']

# %% [markdown]
# ## OOB

# %%
# Evaluate the model
oob_error = 1 - rf_ds.oob_score_
print(f"OOB Error: {oob_error}") # the proportion of misclassified samples among the OOB samples.

# extract the OOB predictions
oob_predictions = rf_ds.oob_decision_function_[:, 1] > 0.5 
# each row corresponds to a sample and each column corresponds to the class probabilities. 
# The first column ([:, 0]) gives the probability of the negative class ("Reject" in our case since it is mapped to 0).
# The second column ([:, 1]) gives the probability of the positive class ("Accept" in our case since it is mapped to 1).
# "True" for predicted as "Reject"

# Convert boolean predictions to integers
oob_predictions_int = oob_predictions.astype(int) # change True to 1 and False to 0 (0: Reject, 1: Accept)

# Calculate the confusion matrix
oob_conf_matrix = confusion_matrix(y_train, oob_predictions_int)
# The confusion matrix is a 2x2 matrix with the following structure:
# [[TN, FP],
# [FN, TP]]

print("OOB Confusion Matrix:")
print(oob_conf_matrix)

# Extract TN, FP, FN, TP from the confusion matrix
TN, FP, FN, TP = oob_conf_matrix.ravel()

# Calculate sensitivity and specificity
oob_sensitivity = TP / (TP + FN)
oob_specificity = TN / (TN + FP)

print(f"Sensitivity (Recall or True Positive Rate): {oob_sensitivity}")
print(f"Specificity (True Negative Rate): {oob_specificity}")

# Plot the confusion matrix with labels
plt.figure(figsize=(7, 5))
sns.heatmap(oob_conf_matrix, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['Predicted Reject', 'Predicted Accept'], # column names
            yticklabels=['Actual Reject', 'Actual Accept']) # row names
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Python OOB Confusion Matrix')
plt.savefig(outdir / "oob_conf_matrix.png")
plt.show()

# Calculate OOB ROC AUC
rf_ds_oob_roc_auc = roc_auc_score(y_train, rf_ds.oob_decision_function_[:, 1])
print(f"OOB ROC AUC: {rf_ds_oob_roc_auc}")

# Plot OOB ROC curve
fpr, tpr, _ = roc_curve(y_train, rf_ds.oob_decision_function_[:, 1])
plt.plot(fpr, tpr, label=f'OOB ROC curve (area = {rf_ds_oob_roc_auc:.2f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Python OOB ROC Curve')
plt.legend(loc='best')
plt.savefig(outdir / "oob_roc_curve.png")
plt.show()
# Out:
# OOB Error: 0.08306364617044226
# OOB Confusion Matrix:
# [[643  72]
#  [  5 207]]
# Sensitivity (Recall or True Positive Rate): 0.9764150943396226
# Specificity (True Negative Rate): 0.8993006993006993
# OOB ROC AUC: 0.9802909354796148

# %% [markdown]
# ## Test set evaluation

# %%
# Predict on test set
rf_ds_pred = rf_ds.predict(X_test)

rf_ds_conf_matrix = confusion_matrix(y_test, rf_ds_pred)
print("Test Set Confusion Matrix:")
print(rf_ds_conf_matrix)

rf_ds_pred_accuracy = accuracy_score(y_test, rf_ds_pred)
print(f"Test Set Accuracy: {rf_ds_pred_accuracy}")

# Extract TN, FP, FN, TP from the confusion matrix and convert to standard Python integers
TN, FP, FN, TP = [int(x) for x in rf_ds_conf_matrix.ravel()]

# Calculate sensitivity and specificity
rf_ds_sensitivity = TP / (TP + FN)
rf_ds_specificity = TN / (TN + FP)

print(f"Sensitivity (Recall or True Positive Rate): {rf_ds_sensitivity}")
print(f"Specificity (True Negative Rate): {rf_ds_specificity}")


rf_ds_pred_prob = rf_ds.predict_proba(X_test)[:, 1]
rf_ds_roc_auc = roc_auc_score(y_test, rf_ds_pred_prob)
print(f"Test Set ROC AUC: {rf_ds_roc_auc}")

plt.figure(figsize=(10, 8))
sns.heatmap(rf_ds_conf_matrix, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['Predicted Reject', 'Predicted Accept'], # column names
            yticklabels=['Actual Reject', 'Actual Accept'], # row names
            annot_kws={'size': 16})  # Make numbers larger
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.xticks(fontsize=16)
#plt.title('Random Forest with Down-samping Test set Confusion Matrix')
plt.savefig(outdir / "rf_ds_test_conf_matrix.png")
plt.show()

#plt.figure(figsize=(10, 8))
fpr, tpr, _ = roc_curve(y_test, rf_ds_pred_prob)
plt.plot(fpr, tpr, label=f'Test Set ROC curve (AUC = {rf_ds_roc_auc:.2f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
#plt.title('Test Set ROC Curve')
plt.legend(loc='best')
plt.savefig(outdir / "rf_ds_test_set_roc_curve.png")
plt.show()
# Out:
# Test Set Confusion Matrix:
# [[208  17]
#  [ 13  72]]
# Test Set Accuracy: 0.9032258064516129
# Sensitivity (Recall or True Positive Rate): 0.8470588235294118
# Specificity (True Negative Rate): 0.9244444444444444
# Test Set ROC AUC: 0.9552679738562092

# %%
from sklearn.metrics import precision_recall_curve, average_precision_score
# For test set predictions
test_precision, test_recall, test_thresholds = precision_recall_curve(y_test, rf_ds.predict_proba(X_test)[:, 1])
test_avg_precision = average_precision_score(y_test, rf_ds.predict_proba(X_test)[:, 1])

#plt.figure(figsize=(8, 6))
plt.plot(test_recall, test_precision, label=f'Test Set PR curve (AP = {test_avg_precision:.2f})')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Test Set Precision-Recall Curve')
plt.legend()
plt.savefig(outdir / "rf_ds_test_set_pr_curve.png")
#plt.grid(True)
plt.show()

# %% [markdown]
# ## Variable of importance
# In scikit-learn's RandomForestClassifier, the feature importance is computed as:
#
# **Mean Decrease in Impurity (MDI)**: The total reduction in impurity (weighted by the number of samples passing through the split) for each feature, averaged across all trees in the forest.
# The feature importance values are normalized so that they sum to 1.

# %%
# Variable importance
importances = rf_ds.feature_importances_
indices = np.argsort(importances)[::-1]
features = X_train.columns

# 
plt.figure(figsize=(10, 8))
#plt.title("Random Forest with Down-Sampling Variable Importance (Top 15)", fontsize=20)
plt.barh(range(15), importances[indices[:15]], align="center")
plt.yticks(range(15), features[indices[:15]], fontsize=16)  # Increase y-tick label size
plt.xticks(fontsize=16)  # Increase x-tick label size
plt.gca().invert_yaxis()  # Invert y-axis to have the most important feature at the top
plt.xlabel('Importance', fontsize=18)
plt.ylabel('Features', fontsize=18)
plt.tight_layout()
plt.savefig(outdir / "rf_ds_variable_importance_top_15.png")
plt.show()

# Plot the bottom 20 variable importance with flipped axes
plt.figure(figsize=(10, 8))
plt.title("Random Forest with Down-Sampling Variable Importance (Bottom 20)")
plt.barh(range(20), importances[indices[-20:]], align="center", color="orange")  # Set bar color to orange
plt.yticks(range(20), features[indices[-20:]])
plt.gca().invert_yaxis()  # Invert y-axis to have the least important feature at the top
plt.xlabel('Importance')
plt.ylabel('Features')
plt.tight_layout()
plt.savefig(outdir / "rf_ds_variable_importance_bottom_20.png")
plt.show()

# %% [markdown]
# # RF with class weighting

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
import joblib

# Define the parameter grid for tuning
param_grid = {
    'max_features': list(range(1, 72)),  # mtry from 1 to 72 since there are 72 features in total
    'n_estimators': list(range(1, 5001, 50))  # ntree from 1 to 5000 with 50 interval
}

# Initialize the RandomForestClassifier with class_weight
rf = RandomForestClassifier(
    class_weight='balanced_subsample',
    random_state=918,
    n_jobs=-1
)

# Set up GridSearchCV
grid_search = GridSearchCV(
    estimator=rf,
    param_grid=param_grid,
    scoring='roc_auc',  # Use AUC for imbalanced data
    cv=3,
    n_jobs=-1,
    verbose=2
)

# Fit the model
grid_search.fit(X_train, y_train)

# Get the best parameters
best_params_classweight = grid_search.best_params_
print("Best parameters:", best_params_classweight)

# Save the best parameters
joblib.dump(best_params_classweight, outdir / "rf_best_params_classweight.pkl")
# Out:
# Fitting 3 folds for each of 7100 candidates, totalling 21300 fits
# [CV] END .....................max_features=1, n_estimators=1; total time=   0.0s
# [CV] END .....................max_features=1, n_estimators=1; total time=   0.0s
# [CV] END .....................max_features=1, n_estimators=1; total time=   0.0s
# [CV] END ....................max_features=1, n_estimators=51; total time=   0.1s
# [CV] END ....................max_features=1, n_estimators=51; total time=   0.2s
# [CV] END ....................max_features=1, n_estimators=51; total time=   0.2s
# [CV] END ...................max_features=1, n_estimators=101; total time=   0.2s
# [CV] END ...................max_features=1, n_estimators=201; total time=   0.4s
# [CV] END ...................max_features=1, n_estimators=101; total time=   0.2s
# [CV] END ...................max_features=1, n_estimators=101; total time=   0.2s
# [CV] END ...................max_features=1, n_estimators=251; total time=   0.5s
# [CV] END ...................max_features=1, n_estimators=251; total time=   0.5s
# [CV] END ...................max_features=1, n_estimators=151; total time=   0.4s
# [CV] END ...................max_features=1, n_estimators=151; total time=   0.5s
# [CV] END ...................max_features=1, n_estimators=251; total time=   0.5s
# [CV] END ...................max_features=1, n_estimators=201; total time=   0.5s
# [CV] END ...................max_features=1, n_estimators=151; total time=   0.5s
# [CV] END ...................max_features=1, n_estimators=301; total time=   0.6s
# [CV] END ...................max_features=1, n_estimators=201; total time=   0.6s
# [CV] END ...................max_features=1, n_estimators=301; total time=   0.6s
# [CV] END ...................max_features=1, n_estimators=301; total time=   0.7s
# [CV] END ...................max_features=1, n_estimators=351; total time=   0.6s
# [CV] END ...................max_features=1, n_estimators=351; total time=   0.7s
# [CV] END ...................max_features=1, n_estimators=401; total time=   0.9s
# [CV] END ...................max_features=1, n_estimators=351; total time=   1.0s
# [CV] END ...................max_features=1, n_estimators=401; total time=   1.0s
# [CV] END ...................max_features=1, n_estimators=451; total time=   0.9s
# [CV] END ...................max_features=1, n_estimators=451; total time=   0.8s
# [CV] END ...................max_features=1, n_estimators=401; total time=   1.1s
# [CV] END ...................max_features=1, n_estimators=451; total time=   1.1s
# [CV] END ...................max_features=1, n_estimators=501; total time=   1.2s
# [CV] END ...................max_features=1, n_estimators=551; total time=   1.2s
# [CV] END ...................max_features=1, n_estimators=501; total time=   1.3s
# [CV] END ...................max_features=1, n_estimators=551; total time=   1.2s
# [CV] END ...................max_features=1, n_estimators=551; total time=   1.3s
# [CV] END ...................max_features=1, n_estimators=501; total time=   1.4s
# [CV] END ...................max_features=1, n_estimators=601; total time=   1.3s
# [CV] END ...................max_features=1, n_estimators=601; total time=   1.1s
# [CV] END ...................max_features=1, n_estimators=601; total time=   1.3s
# [CV] END ...................max_features=1, n_estimators=651; total time=   1.4s
# [CV] END ...................max_features=1, n_estimators=651; total time=   1.4s
# [CV] END ...................max_features=1, n_estimators=651; total time=   1.4s
# [CV] END ...................max_features=1, n_estimators=701; total time=   1.4s
# [CV] END ...................max_features=1, n_estimators=701; total time=   1.5s
# [CV] END ...................max_features=1, n_estimators=701; total time=   1.8s
# [CV] END ...................max_features=1, n_estimators=751; total time=   1.7s
# [CV] END ...................max_features=1, n_estimators=751; total time=   1.7s
# [CV] END ...................max_features=1, n_estimators=751; total time=   1.9s
# [CV] END ...................max_features=1, n_estimators=801; total time=   1.8s
# [CV] END ...................max_features=1, n_estimators=801; total time=   1.9s
# [CV] END ...................max_features=1, n_estimators=801; total time=   1.9s
# [CV] END ...................max_features=1, n_estimators=851; total time=   1.8s
# [CV] END ...................max_features=1, n_estimators=851; total time=   1.8s
# [CV] END ...................max_features=1, n_estimators=851; total time=   1.9s
# [CV] END ...................max_features=1, n_estimators=901; total time=   1.9s
# [CV] END ...................max_features=1, n_estimators=901; total time=   1.9s
# [CV] END ...................max_features=1, n_estimators=901; total time=   1.8s
# [CV] END ...................max_features=1, n_estimators=951; total time=   2.2s
# [CV] END ...................max_features=1, n_estimators=951; total time=   2.1s
# [CV] END ...................max_features=1, n_estimators=951; total time=   2.4s
# [CV] END ..................max_features=1, n_estimators=1001; total time=   2.3s
# [CV] END ..................max_features=1, n_estimators=1001; total time=   2.5s
# [CV] END ..................max_features=1, n_estimators=1001; total time=   2.6s
# [CV] END ..................max_features=1, n_estimators=1051; total time=   2.4s
# [CV] END ..................max_features=1, n_estimators=1051; total time=   2.7s
# [CV] END ..................max_features=1, n_estimators=1101; total time=   2.4s
# [CV] END ..................max_features=1, n_estimators=1051; total time=   2.8s
# [CV] END ..................max_features=1, n_estimators=1101; total time=   2.4s
# [CV] END ..................max_features=1, n_estimators=1101; total time=   2.7s
# [CV] END ..................max_features=1, n_estimators=1151; total time=   2.9s
# [CV] END ..................max_features=1, n_estimators=1151; total time=   3.0s
# [CV] END ..................max_features=1, n_estimators=1151; total time=   2.6s
# [CV] END ..................max_features=1, n_estimators=1201; total time=   2.4s
# [CV] END ..................max_features=1, n_estimators=1201; total time=   2.5s
# [CV] END ..................max_features=1, n_estimators=1201; total time=   2.5s
# [CV] END ..................max_features=1, n_estimators=1251; total time=   2.5s
# [CV] END ..................max_features=1, n_estimators=1251; total time=   2.6s
# [CV] END ..................max_features=1, n_estimators=1301; total time=   2.3s
# [CV] END ..................max_features=1, n_estimators=1251; total time=   2.8s
# [CV] END ..................max_features=1, n_estimators=1301; total time=   2.5s
# [CV] END ..................max_features=1, n_estimators=1301; total time=   2.7s
# [CV] END ..................max_features=1, n_estimators=1351; total time=   2.8s
# [CV] END ..................max_features=1, n_estimators=1351; total time=   2.8s
# [CV] END ..................max_features=1, n_estimators=1351; total time=   2.8s
# [CV] END ..................max_features=1, n_estimators=1401; total time=   2.9s
# [CV] END ..................max_features=1, n_estimators=1401; total time=   2.7s
# [CV] END ..................max_features=1, n_estimators=1401; total time=   3.0s
# [CV] END ..................max_features=1, n_estimators=1451; total time=   2.7s
# [CV] END ..................max_features=1, n_estimators=1451; total time=   2.6s
# [CV] END ..................max_features=1, n_estimators=1451; total time=   2.9s
# [CV] END ..................max_features=1, n_estimators=1501; total time=   2.9s
# [CV] END ..................max_features=1, n_estimators=1501; total time=   3.1s
# [CV] END ..................max_features=1, n_estimators=1501; total time=   3.3s
# [CV] END ..................max_features=1, n_estimators=1551; total time=   3.0s
# [CV] END ..................max_features=1, n_estimators=1551; total time=   2.9s
# [CV] END ..................max_features=1, n_estimators=1551; total time=   3.1s
# [CV] END ..................max_features=1, n_estimators=1601; total time=   3.3s
# [CV] END ..................max_features=1, n_estimators=1601; total time=   3.2s
# [CV] END ..................max_features=1, n_estimators=1601; total time=   3.3s
# [CV] END ..................max_features=1, n_estimators=1651; total time=   3.3s
# [CV] END ..................max_features=1, n_estimators=1651; total time=   3.4s
# [CV] END ..................max_features=1, n_estimators=1651; total time=   3.3s
# [CV] END ..................max_features=1, n_estimators=1701; total time=   3.3s
# [CV] END ..................max_features=1, n_estimators=1701; total time=   3.5s
# [CV] END ..................max_features=1, n_estimators=1701; total time=   3.2s
# [CV] END ..................max_features=1, n_estimators=1751; total time=   3.4s
# [CV] END ..................max_features=1, n_estimators=1751; total time=   3.6s
# [CV] END ..................max_features=1, n_estimators=1751; total time=   3.5s
# [CV] END ..................max_features=1, n_estimators=1801; total time=   3.5s
# [CV] END ..................max_features=1, n_estimators=1801; total time=   3.6s
# [CV] END ..................max_features=1, n_estimators=1801; total time=   3.6s
# [CV] END ..................max_features=1, n_estimators=1851; total time=   3.5s
# [CV] END ..................max_features=1, n_estimators=1851; total time=   3.7s
# [CV] END ..................max_features=1, n_estimators=1851; total time=   3.7s
# [CV] END ..................max_features=1, n_estimators=1901; total time=   3.6s
# [CV] END ..................max_features=1, n_estimators=1901; total time=   3.6s
# [CV] END ..................max_features=1, n_estimators=1901; total time=   3.6s
# [CV] END ..................max_features=1, n_estimators=1951; total time=   3.7s
# [CV] END ..................max_features=1, n_estimators=1951; total time=   3.8s
# [CV] END ..................max_features=1, n_estimators=1951; total time=   3.9s
# [CV] END ..................max_features=1, n_estimators=2001; total time=   3.7s
# [CV] END ..................max_features=1, n_estimators=2001; total time=   3.9s
# [CV] END ..................max_features=1, n_estimators=2001; total time=   3.9s
# [CV] END ..................max_features=1, n_estimators=2051; total time=   4.0s
# [CV] END ..................max_features=1, n_estimators=2051; total time=   3.8s
# [CV] END ..................max_features=1, n_estimators=2051; total time=   3.9s
# [CV] END ..................max_features=1, n_estimators=2101; total time=   4.2s
# [CV] END ..................max_features=1, n_estimators=2101; total time=   4.0s
# [CV] END ..................max_features=1, n_estimators=2151; total time=   3.8s
# [CV] END ..................max_features=1, n_estimators=2101; total time=   4.1s
# [CV] END ..................max_features=1, n_estimators=2151; total time=   3.9s
# [CV] END ..................max_features=1, n_estimators=2151; total time=   4.3s
# [CV] END ..................max_features=1, n_estimators=2201; total time=   4.0s
# [CV] END ..................max_features=1, n_estimators=2201; total time=   4.1s
# [CV] END ..................max_features=1, n_estimators=2201; total time=   4.1s
# [CV] END ..................max_features=1, n_estimators=2251; total time=   4.3s
# [CV] END ..................max_features=1, n_estimators=2251; total time=   4.4s
# [CV] END ..................max_features=1, n_estimators=2251; total time=   4.4s
# [CV] END ..................max_features=1, n_estimators=2301; total time=   4.5s
# [CV] END ..................max_features=1, n_estimators=2301; total time=   4.3s
# [CV] END ..................max_features=1, n_estimators=2301; total time=   4.3s
# [CV] END ..................max_features=1, n_estimators=2351; total time=   4.4s
# [CV] END ..................max_features=1, n_estimators=2351; total time=   4.3s
# [CV] END ..................max_features=1, n_estimators=2351; total time=   4.4s
# [CV] END ..................max_features=1, n_estimators=2401; total time=   4.3s
# [CV] END ..................max_features=1, n_estimators=2401; total time=   4.5s
# [CV] END ..................max_features=1, n_estimators=2401; total time=   4.4s
# [CV] END ..................max_features=1, n_estimators=2451; total time=   4.5s
# [CV] END ..................max_features=1, n_estimators=2451; total time=   4.4s
# [CV] END ..................max_features=1, n_estimators=2451; total time=   4.7s
# [CV] END ..................max_features=1, n_estimators=2501; total time=   4.6s
# [CV] END ..................max_features=1, n_estimators=2501; total time=   4.7s
# [CV] END ..................max_features=1, n_estimators=2551; total time=   4.7s
# [CV] END ..................max_features=1, n_estimators=2501; total time=   4.8s
# [CV] END ..................max_features=1, n_estimators=2551; total time=   4.6s
# [CV] END ..................max_features=1, n_estimators=2601; total time=   4.6s
# [CV] END ..................max_features=1, n_estimators=2551; total time=   4.7s
# [CV] END ..................max_features=1, n_estimators=2601; total time=   4.8s
# [CV] END ..................max_features=1, n_estimators=2601; total time=   4.9s
# [CV] END ..................max_features=1, n_estimators=2651; total time=   5.0s
# [CV] END ..................max_features=1, n_estimators=2651; total time=   5.1s
# [CV] END ..................max_features=1, n_estimators=2701; total time=   4.9s
# [CV] END ..................max_features=1, n_estimators=2701; total time=   4.8s
# [CV] END ..................max_features=1, n_estimators=2651; total time=   5.0s
# [CV] END ..................max_features=1, n_estimators=2701; total time=   5.2s
# [CV] END ..................max_features=1, n_estimators=2751; total time=   5.1s
# [CV] END ..................max_features=1, n_estimators=2751; total time=   4.8s
# [CV] END ..................max_features=1, n_estimators=2751; total time=   5.4s
# [CV] END ..................max_features=1, n_estimators=2801; total time=   5.0s
# [CV] END ..................max_features=1, n_estimators=2801; total time=   5.3s
# [CV] END ..................max_features=1, n_estimators=2801; total time=   5.1s
# [CV] END ..................max_features=1, n_estimators=2851; total time=   5.3s
# [CV] END ..................max_features=1, n_estimators=2851; total time=   5.3s
# [CV] END ..................max_features=1, n_estimators=2851; total time=   5.3s
# [CV] END ..................max_features=1, n_estimators=2901; total time=   5.6s
# [CV] END ..................max_features=1, n_estimators=2901; total time=   5.3s
# [CV] END ..................max_features=1, n_estimators=2901; total time=   5.4s
# [CV] END ..................max_features=1, n_estimators=2951; total time=   5.6s
# [CV] END ..................max_features=1, n_estimators=2951; total time=   5.7s
# [CV] END ..................max_features=1, n_estimators=2951; total time=   5.5s
# [CV] END ..................max_features=1, n_estimators=3001; total time=   5.6s
# [CV] END ..................max_features=1, n_estimators=3001; total time=   5.6s
# [CV] END ..................max_features=1, n_estimators=3001; total time=   6.0s
# [CV] END ..................max_features=1, n_estimators=3051; total time=   5.7s
# [CV] END ..................max_features=1, n_estimators=3051; total time=   5.8s
# [CV] END ..................max_features=1, n_estimators=3051; total time=   5.8s
# [CV] END ..................max_features=1, n_estimators=3101; total time=   6.0s
# [CV] END ..................max_features=1, n_estimators=3101; total time=   5.8s
# [CV] END ..................max_features=1, n_estimators=3101; total time=   6.0s
# [CV] END ..................max_features=1, n_estimators=3151; total time=   5.8s
# [CV] END ..................max_features=1, n_estimators=3151; total time=   5.9s
# [CV] END ..................max_features=1, n_estimators=3151; total time=   6.3s
# [CV] END ..................max_features=1, n_estimators=3201; total time=   6.0s
# [CV] END ..................max_features=1, n_estimators=3201; total time=   6.0s
# [CV] END ..................max_features=1, n_estimators=3201; total time=   6.1s
# [CV] END ..................max_features=1, n_estimators=3251; total time=   5.8s
# [CV] END ..................max_features=1, n_estimators=3251; total time=   5.9s
# [CV] END ..................max_features=1, n_estimators=3251; total time=   6.1s
# [CV] END ..................max_features=1, n_estimators=3301; total time=   6.2s
# [CV] END ..................max_features=1, n_estimators=3301; total time=   6.3s
# [CV] END ..................max_features=1, n_estimators=3301; total time=   6.4s
# [CV] END ..................max_features=1, n_estimators=3351; total time=   6.4s
# [CV] END ..................max_features=1, n_estimators=3351; total time=   5.9s
# [CV] END ..................max_features=1, n_estimators=3351; total time=   6.1s
# [CV] END ..................max_features=1, n_estimators=3401; total time=   6.3s
# [CV] END ..................max_features=1, n_estimators=3401; total time=   6.4s
# [CV] END ..................max_features=1, n_estimators=3401; total time=   6.5s
# [CV] END ..................max_features=1, n_estimators=3451; total time=   6.4s
# [CV] END ..................max_features=1, n_estimators=3451; total time=   6.5s
# [CV] END ..................max_features=1, n_estimators=3451; total time=   6.3s
# [CV] END ..................max_features=1, n_estimators=3501; total time=   6.6s
# [CV] END ..................max_features=1, n_estimators=3501; total time=   6.6s
# [CV] END ..................max_features=1, n_estimators=3501; total time=   6.9s
# [CV] END ..................max_features=1, n_estimators=3551; total time=   6.6s
# [CV] END ..................max_features=1, n_estimators=3551; total time=   6.7s
# [CV] END ..................max_features=1, n_estimators=3551; total time=   6.6s
# [CV] END ..................max_features=1, n_estimators=3601; total time=   6.9s
# [CV] END ..................max_features=1, n_estimators=3601; total time=   7.0s
# [CV] END ..................max_features=1, n_estimators=3601; total time=   6.7s
# [CV] END ..................max_features=1, n_estimators=3651; total time=   6.8s
# [CV] END ..................max_features=1, n_estimators=3651; total time=   6.9s
# [CV] END ..................max_features=1, n_estimators=3651; total time=   6.8s
# [CV] END ..................max_features=1, n_estimators=3701; total time=   7.0s
# [CV] END ..................max_features=1, n_estimators=3701; total time=   6.7s
# [CV] END ..................max_features=1, n_estimators=3701; total time=   6.7s
# [CV] END ..................max_features=1, n_estimators=3751; total time=   7.1s
# [CV] END ..................max_features=1, n_estimators=3751; total time=   7.1s
# [CV] END ..................max_features=1, n_estimators=3751; total time=   7.1s
# [CV] END ..................max_features=1, n_estimators=3801; total time=   7.2s
# [CV] END ..................max_features=1, n_estimators=3801; total time=   7.3s
# [CV] END ..................max_features=1, n_estimators=3851; total time=   7.0s
# [CV] END ..................max_features=1, n_estimators=3801; total time=   7.2s
# [CV] END ..................max_features=1, n_estimators=3851; total time=   6.9s
# [CV] END ..................max_features=1, n_estimators=3851; total time=   7.4s
# [CV] END ..................max_features=1, n_estimators=3901; total time=   7.4s
# [CV] END ..................max_features=1, n_estimators=3901; total time=   7.3s
# [CV] END ..................max_features=1, n_estimators=3901; total time=   7.0s
# [CV] END ..................max_features=1, n_estimators=3951; total time=   7.1s
# [CV] END ..................max_features=1, n_estimators=3951; total time=   7.4s
# [CV] END ..................max_features=1, n_estimators=3951; total time=   7.4s
# [CV] END ..................max_features=1, n_estimators=4001; total time=   7.6s
# [CV] END ..................max_features=1, n_estimators=4001; total time=   7.6s
# [CV] END ..................max_features=1, n_estimators=4001; total time=   7.5s
# [CV] END ..................max_features=1, n_estimators=4051; total time=   7.6s
# [CV] END ..................max_features=1, n_estimators=4051; total time=   7.5s
# [CV] END ..................max_features=1, n_estimators=4051; total time=   7.9s
# [CV] END ..................max_features=1, n_estimators=4101; total time=   7.5s
# [CV] END ..................max_features=1, n_estimators=4101; total time=   7.8s
# [CV] END ..................max_features=1, n_estimators=4101; total time=   7.5s
# [CV] END ..................max_features=1, n_estimators=4151; total time=   7.7s
# [CV] END ..................max_features=1, n_estimators=4151; total time=   7.7s
# [CV] END ..................max_features=1, n_estimators=4151; total time=   7.6s
# [CV] END ..................max_features=1, n_estimators=4201; total time=   8.0s
# [CV] END ..................max_features=1, n_estimators=4201; total time=   8.2s
# [CV] END ..................max_features=1, n_estimators=4201; total time=   8.0s
# [CV] END ..................max_features=1, n_estimators=4251; total time=   7.9s
# [CV] END ..................max_features=1, n_estimators=4251; total time=   8.0s
# [CV] END ..................max_features=1, n_estimators=4251; total time=   8.1s
# [CV] END ..................max_features=1, n_estimators=4301; total time=   8.1s
# [CV] END ..................max_features=1, n_estimators=4301; total time=   7.9s
# [CV] END ..................max_features=1, n_estimators=4301; total time=   7.9s
# [CV] END ..................max_features=1, n_estimators=4351; total time=   8.4s
# [CV] END ..................max_features=1, n_estimators=4351; total time=   8.3s
# [CV] END ..................max_features=1, n_estimators=4351; total time=   8.1s
# [CV] END ..................max_features=1, n_estimators=4401; total time=   8.2s
# [CV] END ..................max_features=1, n_estimators=4401; total time=   8.2s
# [CV] END ..................max_features=1, n_estimators=4401; total time=   8.3s
# [CV] END ..................max_features=1, n_estimators=4451; total time=   8.2s
# [CV] END ..................max_features=1, n_estimators=4451; total time=   8.4s
# [CV] END ..................max_features=1, n_estimators=4451; total time=   8.4s
# [CV] END ..................max_features=1, n_estimators=4501; total time=   8.2s
# [CV] END ..................max_features=1, n_estimators=4501; total time=   8.6s
# [CV] END ..................max_features=1, n_estimators=4501; total time=   8.5s
# [CV] END ..................max_features=1, n_estimators=4551; total time=   8.5s
# [CV] END ..................max_features=1, n_estimators=4551; total time=   8.4s
# [CV] END ..................max_features=1, n_estimators=4551; total time=   8.7s
# [CV] END ..................max_features=1, n_estimators=4601; total time=   8.5s
# [CV] END ..................max_features=1, n_estimators=4601; total time=   8.5s
# [CV] END ..................max_features=1, n_estimators=4601; total time=   8.2s
# [CV] END ..................max_features=1, n_estimators=4651; total time=   8.7s
# [CV] END ..................max_features=1, n_estimators=4651; total time=   8.9s
# [CV] END ..................max_features=1, n_estimators=4651; total time=   8.6s
# [CV] END ..................max_features=1, n_estimators=4701; total time=   9.0s
# [CV] END ..................max_features=1, n_estimators=4701; total time=   9.1s
# [CV] END ..................max_features=1, n_estimators=4701; total time=   8.7s
# [CV] END ..................max_features=1, n_estimators=4751; total time=   9.0s
# [CV] END ..................max_features=1, n_estimators=4751; total time=   8.9s
# [CV] END .....................max_features=2, n_estimators=1; total time=   0.0s
# [CV] END .....................max_features=2, n_estimators=1; total time=   0.0s
# [CV] END .....................max_features=2, n_estimators=1; total time=   0.0s
# [CV] END ..................max_features=1, n_estimators=4751; total time=   9.0s
# [CV] END ....................max_features=2, n_estimators=51; total time=   0.1s
# [CV] END ....................max_features=2, n_estimators=51; total time=   0.1s
# [CV] END ..................max_features=1, n_estimators=4801; total time=   9.0s
# [CV] END ...................max_features=2, n_estimators=101; total time=   0.2s
# [CV] END ....................max_features=2, n_estimators=51; total time=   0.2s
# [CV] END ...................max_features=2, n_estimators=101; total time=   0.3s
# [CV] END ...................max_features=2, n_estimators=101; total time=   0.2s
# [CV] END ...................max_features=2, n_estimators=151; total time=   0.4s
# [CV] END ...................max_features=2, n_estimators=151; total time=   0.4s
# [CV] END ...................max_features=2, n_estimators=151; total time=   0.3s
# [CV] END ...................max_features=2, n_estimators=201; total time=   0.5s
# [CV] END ...................max_features=2, n_estimators=201; total time=   0.4s
# [CV] END ...................max_features=2, n_estimators=201; total time=   0.4s
# [CV] END ...................max_features=2, n_estimators=251; total time=   0.5s
# [CV] END ...................max_features=2, n_estimators=251; total time=   0.6s
# [CV] END ..................max_features=1, n_estimators=4801; total time=   9.1s
# [CV] END ...................max_features=2, n_estimators=251; total time=   0.5s
# [CV] END ...................max_features=2, n_estimators=301; total time=   0.7s
# [CV] END ..................max_features=1, n_estimators=4851; total time=   9.2s
# [CV] END ...................max_features=2, n_estimators=301; total time=   0.7s
# [CV] END ...................max_features=2, n_estimators=301; total time=   0.8s
# [CV] END ...................max_features=2, n_estimators=351; total time=   0.8s
# [CV] END ..................max_features=1, n_estimators=4801; total time=   9.5s
# [CV] END ...................max_features=2, n_estimators=351; total time=   0.8s
# [CV] END ...................max_features=2, n_estimators=351; total time=   0.8s
# [CV] END ..................max_features=1, n_estimators=4851; total time=   9.6s
# [CV] END ...................max_features=2, n_estimators=401; total time=   0.9s
# [CV] END ...................max_features=2, n_estimators=401; total time=   0.9s
# [CV] END ...................max_features=2, n_estimators=401; total time=   0.8s
# [CV] END ...................max_features=2, n_estimators=451; total time=   1.0s
# [CV] END ..................max_features=1, n_estimators=4851; total time=   9.5s
# [CV] END ...................max_features=2, n_estimators=501; total time=   0.9s
# [CV] END ...................max_features=2, n_estimators=451; total time=   1.0s
# [CV] END ...................max_features=2, n_estimators=451; total time=   1.1s
# [CV] END ...................max_features=2, n_estimators=501; total time=   1.0s
# [CV] END ...................max_features=2, n_estimators=501; total time=   1.1s
# [CV] END ...................max_features=2, n_estimators=551; total time=   1.2s
# [CV] END ...................max_features=2, n_estimators=551; total time=   1.1s
# [CV] END ...................max_features=2, n_estimators=551; total time=   1.1s
# [CV] END ..................max_features=1, n_estimators=4901; total time=   9.4s
# [CV] END ...................max_features=2, n_estimators=601; total time=   1.3s
# [CV] END ...................max_features=2, n_estimators=601; total time=   1.3s
# [CV] END ...................max_features=2, n_estimators=601; total time=   1.5s
# [CV] END ...................max_features=2, n_estimators=651; total time=   1.4s
# [CV] END ...................max_features=2, n_estimators=651; total time=   1.3s
# [CV] END ...................max_features=2, n_estimators=651; total time=   1.3s
# [CV] END ...................max_features=2, n_estimators=701; total time=   1.4s
# [CV] END ...................max_features=2, n_estimators=701; total time=   1.3s
# [CV] END ..................max_features=1, n_estimators=4901; total time=   9.9s
# [CV] END ...................max_features=2, n_estimators=701; total time=   1.5s
# [CV] END ..................max_features=1, n_estimators=4901; total time=   9.8s
# [CV] END ...................max_features=2, n_estimators=751; total time=   1.6s
# [CV] END ...................max_features=2, n_estimators=751; total time=   1.6s
# [CV] END ...................max_features=2, n_estimators=751; total time=   1.5s
# [CV] END ...................max_features=2, n_estimators=801; total time=   1.8s
# [CV] END ...................max_features=2, n_estimators=801; total time=   1.8s
# [CV] END ...................max_features=2, n_estimators=801; total time=   1.7s
# [CV] END ..................max_features=1, n_estimators=4951; total time=  10.3s
# [CV] END ...................max_features=2, n_estimators=851; total time=   1.8s
# [CV] END ...................max_features=2, n_estimators=851; total time=   1.6s
# [CV] END ...................max_features=2, n_estimators=901; total time=   1.7s
# [CV] END ...................max_features=2, n_estimators=851; total time=   1.8s
# [CV] END ..................max_features=1, n_estimators=4951; total time=  10.1s
# [CV] END ...................max_features=2, n_estimators=901; total time=   1.9s
# [CV] END ...................max_features=2, n_estimators=901; total time=   1.9s
# [CV] END ...................max_features=2, n_estimators=951; total time=   1.8s
# [CV] END ..................max_features=1, n_estimators=4951; total time=  10.3s
# [CV] END ...................max_features=2, n_estimators=951; total time=   1.7s
# [CV] END ...................max_features=2, n_estimators=951; total time=   2.1s
# [CV] END ..................max_features=2, n_estimators=1001; total time=   1.8s
# [CV] END ..................max_features=2, n_estimators=1001; total time=   2.0s
# [CV] END ..................max_features=2, n_estimators=1001; total time=   2.0s
# [CV] END ..................max_features=2, n_estimators=1051; total time=   2.1s
# [CV] END ..................max_features=2, n_estimators=1051; total time=   2.1s
# [CV] END ..................max_features=2, n_estimators=1051; total time=   2.0s
# [CV] END ..................max_features=2, n_estimators=1101; total time=   2.1s
# [CV] END ..................max_features=2, n_estimators=1101; total time=   2.0s
# [CV] END ..................max_features=2, n_estimators=1101; total time=   2.1s
# [CV] END ..................max_features=2, n_estimators=1151; total time=   2.1s
# [CV] END ..................max_features=2, n_estimators=1151; total time=   2.2s
# [CV] END ..................max_features=2, n_estimators=1151; total time=   2.5s
# [CV] END ..................max_features=2, n_estimators=1201; total time=   2.3s
# [CV] END ..................max_features=2, n_estimators=1201; total time=   2.5s
# [CV] END ..................max_features=2, n_estimators=1251; total time=   2.1s
# [CV] END ..................max_features=2, n_estimators=1201; total time=   2.5s
# [CV] END ..................max_features=2, n_estimators=1251; total time=   2.2s
# [CV] END ..................max_features=2, n_estimators=1301; total time=   2.3s
# [CV] END ..................max_features=2, n_estimators=1251; total time=   2.5s
# [CV] END ..................max_features=2, n_estimators=1301; total time=   2.3s
# [CV] END ..................max_features=2, n_estimators=1301; total time=   2.5s
# [CV] END ..................max_features=2, n_estimators=1351; total time=   2.7s
# [CV] END ..................max_features=2, n_estimators=1351; total time=   2.5s
# [CV] END ..................max_features=2, n_estimators=1351; total time=   2.6s
# [CV] END ..................max_features=2, n_estimators=1401; total time=   2.6s
# [CV] END ..................max_features=2, n_estimators=1401; total time=   2.8s
# [CV] END ..................max_features=2, n_estimators=1401; total time=   2.8s
# [CV] END ..................max_features=2, n_estimators=1451; total time=   2.7s
# [CV] END ..................max_features=2, n_estimators=1451; total time=   2.5s
# [CV] END ..................max_features=2, n_estimators=1451; total time=   2.7s
# [CV] END ..................max_features=2, n_estimators=1501; total time=   2.9s
# [CV] END ..................max_features=2, n_estimators=1551; total time=   2.8s
# [CV] END ..................max_features=2, n_estimators=1501; total time=   3.2s
# [CV] END ..................max_features=2, n_estimators=1501; total time=   3.0s
# [CV] END ..................max_features=2, n_estimators=1551; total time=   2.9s
# [CV] END ..................max_features=2, n_estimators=1551; total time=   3.1s
# [CV] END ..................max_features=2, n_estimators=1601; total time=   3.0s
# [CV] END ..................max_features=2, n_estimators=1601; total time=   3.2s
# [CV] END ..................max_features=2, n_estimators=1601; total time=   3.1s
# [CV] END ..................max_features=2, n_estimators=1651; total time=   3.0s
# [CV] END ..................max_features=2, n_estimators=1651; total time=   3.1s
# [CV] END ..................max_features=2, n_estimators=1651; total time=   3.4s
# [CV] END ..................max_features=2, n_estimators=1701; total time=   3.2s
# [CV] END ..................max_features=2, n_estimators=1701; total time=   3.3s
# [CV] END ..................max_features=2, n_estimators=1701; total time=   3.4s
# [CV] END ..................max_features=2, n_estimators=1751; total time=   3.1s
# [CV] END ..................max_features=2, n_estimators=1751; total time=   3.2s
# [CV] END ..................max_features=2, n_estimators=1751; total time=   3.4s
# [CV] END ..................max_features=2, n_estimators=1801; total time=   3.6s
# [CV] END ..................max_features=2, n_estimators=1801; total time=   3.1s
# [CV] END ..................max_features=2, n_estimators=1801; total time=   3.2s
# [CV] END ..................max_features=2, n_estimators=1851; total time=   3.3s
# [CV] END ..................max_features=2, n_estimators=1851; total time=   3.5s
# [CV] END ..................max_features=2, n_estimators=1851; total time=   3.5s
# [CV] END ..................max_features=2, n_estimators=1901; total time=   3.5s
# [CV] END ..................max_features=2, n_estimators=1901; total time=   3.6s
# [CV] END ..................max_features=2, n_estimators=1901; total time=   3.7s
# [CV] END ..................max_features=2, n_estimators=1951; total time=   3.9s
# [CV] END ..................max_features=2, n_estimators=1951; total time=   3.6s
# [CV] END ..................max_features=2, n_estimators=1951; total time=   3.3s
# [CV] END ..................max_features=2, n_estimators=2001; total time=   3.5s
# [CV] END ..................max_features=2, n_estimators=2001; total time=   3.8s
# [CV] END ..................max_features=2, n_estimators=2001; total time=   3.8s
# [CV] END ..................max_features=2, n_estimators=2051; total time=   3.9s
# [CV] END ..................max_features=2, n_estimators=2051; total time=   3.8s
# [CV] END ..................max_features=2, n_estimators=2051; total time=   4.0s
# [CV] END ..................max_features=2, n_estimators=2101; total time=   4.0s
# [CV] END ..................max_features=2, n_estimators=2101; total time=   4.0s
# [CV] END ..................max_features=2, n_estimators=2101; total time=   3.8s
# [CV] END ..................max_features=2, n_estimators=2151; total time=   4.0s
# [CV] END ..................max_features=2, n_estimators=2151; total time=   4.2s
# [CV] END ..................max_features=2, n_estimators=2151; total time=   4.0s
# [CV] END ..................max_features=2, n_estimators=2201; total time=   4.1s
# [CV] END ..................max_features=2, n_estimators=2201; total time=   4.3s
# [CV] END ..................max_features=2, n_estimators=2201; total time=   4.5s
# [CV] END ..................max_features=2, n_estimators=2251; total time=   4.4s
# [CV] END ..................max_features=2, n_estimators=2251; total time=   4.3s
# [CV] END ..................max_features=2, n_estimators=2251; total time=   4.3s
# [CV] END ..................max_features=2, n_estimators=2301; total time=   4.2s
# [CV] END ..................max_features=2, n_estimators=2301; total time=   4.5s
# [CV] END ..................max_features=2, n_estimators=2351; total time=   4.3s
# [CV] END ..................max_features=2, n_estimators=2301; total time=   4.6s
# [CV] END ..................max_features=2, n_estimators=2351; total time=   4.3s
# [CV] END ..................max_features=2, n_estimators=2351; total time=   4.5s
# [CV] END ..................max_features=2, n_estimators=2401; total time=   4.4s
# [CV] END ..................max_features=2, n_estimators=2401; total time=   4.5s
# [CV] END ..................max_features=2, n_estimators=2401; total time=   4.5s
# [CV] END ..................max_features=2, n_estimators=2451; total time=   4.8s
# [CV] END ..................max_features=2, n_estimators=2451; total time=   4.9s
# [CV] END ..................max_features=2, n_estimators=2451; total time=   4.6s
# [CV] END ..................max_features=2, n_estimators=2501; total time=   4.6s
# [CV] END ..................max_features=2, n_estimators=2501; total time=   4.6s
# [CV] END ..................max_features=2, n_estimators=2501; total time=   4.7s
# [CV] END ..................max_features=2, n_estimators=2551; total time=   4.9s
# [CV] END ..................max_features=2, n_estimators=2551; total time=   4.7s
# [CV] END ..................max_features=2, n_estimators=2551; total time=   5.0s
# [CV] END ..................max_features=2, n_estimators=2601; total time=   4.8s
# [CV] END ..................max_features=2, n_estimators=2601; total time=   5.0s
# [CV] END ..................max_features=2, n_estimators=2601; total time=   4.8s
# [CV] END ..................max_features=2, n_estimators=2651; total time=   5.0s
# [CV] END ..................max_features=2, n_estimators=2651; total time=   4.9s
# [CV] END ..................max_features=2, n_estimators=2651; total time=   5.0s
# [CV] END ..................max_features=2, n_estimators=2701; total time=   5.2s
# [CV] END ..................max_features=2, n_estimators=2701; total time=   5.2s
# [CV] END ..................max_features=2, n_estimators=2751; total time=   5.0s
# [CV] END ..................max_features=2, n_estimators=2751; total time=   5.0s
# [CV] END ..................max_features=2, n_estimators=2701; total time=   5.3s
# [CV] END ..................max_features=2, n_estimators=2751; total time=   5.2s
# [CV] END ..................max_features=2, n_estimators=2801; total time=   5.1s
# [CV] END ..................max_features=2, n_estimators=2801; total time=   5.1s
# [CV] END ..................max_features=2, n_estimators=2801; total time=   5.2s
# [CV] END ..................max_features=2, n_estimators=2851; total time=   5.5s
# [CV] END ..................max_features=2, n_estimators=2851; total time=   5.2s
# [CV] END ..................max_features=2, n_estimators=2851; total time=   5.4s
# [CV] END ..................max_features=2, n_estimators=2901; total time=   5.3s
# [CV] END ..................max_features=2, n_estimators=2901; total time=   5.6s
# [CV] END ..................max_features=2, n_estimators=2901; total time=   5.5s
# [CV] END ..................max_features=2, n_estimators=2951; total time=   5.5s
# [CV] END ..................max_features=2, n_estimators=2951; total time=   5.5s
# [CV] END ..................max_features=2, n_estimators=2951; total time=   5.6s
# [CV] END ..................max_features=2, n_estimators=3001; total time=   5.6s
# [CV] END ..................max_features=2, n_estimators=3001; total time=   5.6s
# [CV] END ..................max_features=2, n_estimators=3001; total time=   5.4s
# [CV] END ..................max_features=2, n_estimators=3051; total time=   5.5s
# [CV] END ..................max_features=2, n_estimators=3051; total time=   5.6s
# [CV] END ..................max_features=2, n_estimators=3051; total time=   5.9s
# [CV] END ..................max_features=2, n_estimators=3101; total time=   5.9s
# [CV] END ..................max_features=2, n_estimators=3101; total time=   5.7s
# [CV] END ..................max_features=2, n_estimators=3101; total time=   5.9s
# [CV] END ..................max_features=2, n_estimators=3151; total time=   5.7s
# [CV] END ..................max_features=2, n_estimators=3151; total time=   5.7s
# [CV] END ..................max_features=2, n_estimators=3151; total time=   5.9s
# [CV] END ..................max_features=2, n_estimators=3201; total time=   5.9s
# [CV] END ..................max_features=2, n_estimators=3201; total time=   6.0s
# [CV] END ..................max_features=2, n_estimators=3201; total time=   5.8s
# [CV] END ..................max_features=2, n_estimators=3251; total time=   5.8s
# [CV] END ..................max_features=2, n_estimators=3251; total time=   5.9s
# [CV] END ..................max_features=2, n_estimators=3251; total time=   5.9s
# [CV] END ..................max_features=2, n_estimators=3301; total time=   6.1s
# [CV] END ..................max_features=2, n_estimators=3301; total time=   5.7s
# [CV] END ..................max_features=2, n_estimators=3301; total time=   6.0s
# [CV] END ..................max_features=2, n_estimators=3351; total time=   5.9s
# [CV] END ..................max_features=2, n_estimators=3351; total time=   5.9s
# [CV] END ..................max_features=2, n_estimators=3351; total time=   6.2s
# [CV] END ..................max_features=2, n_estimators=3401; total time=   6.0s
# [CV] END ..................max_features=2, n_estimators=3401; total time=   6.3s
# [CV] END ..................max_features=2, n_estimators=3401; total time=   6.1s
# [CV] END ..................max_features=2, n_estimators=3451; total time=   6.0s
# [CV] END ..................max_features=2, n_estimators=3451; total time=   6.1s
# [CV] END ..................max_features=2, n_estimators=3451; total time=   6.2s
# [CV] END ..................max_features=2, n_estimators=3501; total time=   6.4s
# [CV] END ..................max_features=2, n_estimators=3501; total time=   6.2s
# [CV] END ..................max_features=2, n_estimators=3501; total time=   6.5s
# [CV] END ..................max_features=2, n_estimators=3551; total time=   6.7s
# [CV] END ..................max_features=2, n_estimators=3551; total time=   6.4s
# [CV] END ..................max_features=2, n_estimators=3551; total time=   6.5s
# [CV] END ..................max_features=2, n_estimators=3601; total time=   6.5s
# [CV] END ..................max_features=2, n_estimators=3601; total time=   6.5s
# [CV] END ..................max_features=2, n_estimators=3601; total time=   6.7s
# [CV] END ..................max_features=2, n_estimators=3651; total time=   6.7s
# [CV] END ..................max_features=2, n_estimators=3651; total time=   6.7s
# [CV] END ..................max_features=2, n_estimators=3701; total time=   6.8s
# [CV] END ..................max_features=2, n_estimators=3651; total time=   7.0s
# [CV] END ..................max_features=2, n_estimators=3701; total time=   7.0s
# [CV] END ..................max_features=2, n_estimators=3701; total time=   7.2s
# [CV] END ..................max_features=2, n_estimators=3751; total time=   7.0s
# [CV] END ..................max_features=2, n_estimators=3751; total time=   7.2s
# [CV] END ..................max_features=2, n_estimators=3801; total time=   7.1s
# [CV] END ..................max_features=2, n_estimators=3751; total time=   7.1s
# [CV] END ..................max_features=2, n_estimators=3801; total time=   7.0s
# [CV] END ..................max_features=2, n_estimators=3801; total time=   7.4s
# [CV] END ..................max_features=2, n_estimators=3851; total time=   7.5s
# [CV] END ..................max_features=2, n_estimators=3851; total time=   7.5s
# [CV] END ..................max_features=2, n_estimators=3851; total time=   7.3s
# [CV] END ..................max_features=2, n_estimators=3901; total time=   7.0s
# [CV] END ..................max_features=2, n_estimators=3901; total time=   7.3s
# [CV] END ..................max_features=2, n_estimators=3901; total time=   7.5s
# [CV] END ..................max_features=2, n_estimators=3951; total time=   7.4s
# [CV] END ..................max_features=2, n_estimators=3951; total time=   7.7s
# [CV] END ..................max_features=2, n_estimators=3951; total time=   7.4s
# [CV] END ..................max_features=2, n_estimators=4001; total time=   7.4s
# [CV] END ..................max_features=2, n_estimators=4001; total time=   7.6s
# [CV] END ..................max_features=2, n_estimators=4001; total time=   7.6s
# [CV] END ..................max_features=2, n_estimators=4051; total time=   7.3s
# [CV] END ..................max_features=2, n_estimators=4051; total time=   7.4s
# [CV] END ..................max_features=2, n_estimators=4051; total time=   7.5s
# [CV] END ..................max_features=2, n_estimators=4101; total time=   7.5s
# [CV] END ..................max_features=2, n_estimators=4101; total time=   7.2s
# [CV] END ..................max_features=2, n_estimators=4101; total time=   7.7s
# [CV] END ..................max_features=2, n_estimators=4151; total time=   7.8s
# [CV] END ..................max_features=2, n_estimators=4151; total time=   7.7s
# [CV] END ..................max_features=2, n_estimators=4151; total time=   8.0s
# [CV] END ..................max_features=2, n_estimators=4201; total time=   7.6s
# [CV] END ..................max_features=2, n_estimators=4201; total time=   7.8s
# [CV] END ..................max_features=2, n_estimators=4201; total time=   7.9s
# [CV] END ..................max_features=2, n_estimators=4251; total time=   7.7s
# [CV] END ..................max_features=2, n_estimators=4251; total time=   8.0s
# [CV] END ..................max_features=2, n_estimators=4251; total time=   8.2s
# [CV] END ..................max_features=2, n_estimators=4301; total time=   7.7s
# [CV] END ..................max_features=2, n_estimators=4301; total time=   8.2s
# [CV] END ..................max_features=2, n_estimators=4301; total time=   8.0s
# [CV] END ..................max_features=2, n_estimators=4351; total time=   7.9s
# [CV] END ..................max_features=2, n_estimators=4351; total time=   8.4s
# [CV] END ..................max_features=2, n_estimators=4351; total time=   8.1s
# [CV] END ..................max_features=2, n_estimators=4401; total time=   8.2s
# [CV] END ..................max_features=2, n_estimators=4401; total time=   8.2s
# [CV] END ..................max_features=2, n_estimators=4451; total time=   7.9s
# [CV] END ..................max_features=2, n_estimators=4451; total time=   7.9s
# [CV] END ..................max_features=2, n_estimators=4401; total time=   8.0s
# [CV] END ..................max_features=2, n_estimators=4501; total time=   8.1s
# [CV] END ..................max_features=2, n_estimators=4451; total time=   8.3s
# [CV] END ..................max_features=2, n_estimators=4501; total time=   8.1s
# [CV] END ..................max_features=2, n_estimators=4501; total time=   8.4s
# [CV] END ..................max_features=2, n_estimators=4551; total time=   8.3s
# [CV] END ..................max_features=2, n_estimators=4551; total time=   8.5s
# [CV] END ..................max_features=2, n_estimators=4551; total time=   8.5s
# [CV] END ..................max_features=2, n_estimators=4601; total time=   8.2s
# [CV] END ..................max_features=2, n_estimators=4601; total time=   8.5s
# [CV] END ..................max_features=2, n_estimators=4601; total time=   8.8s
# [CV] END ..................max_features=2, n_estimators=4651; total time=   8.3s
# [CV] END ..................max_features=2, n_estimators=4651; total time=   8.9s
# [CV] END ..................max_features=2, n_estimators=4651; total time=   8.5s
# [CV] END ..................max_features=2, n_estimators=4701; total time=   8.5s
# [CV] END ..................max_features=2, n_estimators=4701; total time=   8.6s
# [CV] END ..................max_features=2, n_estimators=4751; total time=   8.5s
# [CV] END ..................max_features=2, n_estimators=4701; total time=   8.7s
# [CV] END ..................max_features=2, n_estimators=4751; total time=   8.6s
# [CV] END .....................max_features=3, n_estimators=1; total time=   0.0s
# [CV] END .....................max_features=3, n_estimators=1; total time=   0.0s
# [CV] END .....................max_features=3, n_estimators=1; total time=   0.0s
# [CV] END ....................max_features=3, n_estimators=51; total time=   0.2s
# ...
# [CV] END .................max_features=71, n_estimators=1751; total time=  20.4s
# [CV] END .................max_features=71, n_estimators=1751; total time=  18.8s
# [CV] END .................max_features=71, n_estimators=1801; total time=  17.9s
# [CV] END .................max_features=71, n_estimators=1801; total time=  20.0s
# [CV] END .................max_features=71, n_estimators=1851; total time=  19.4s
# [CV] END .................max_features=71, n_estimators=1801; total time=  21.0s
# [CV] END .................max_features=71, n_estimators=1851; total time=  20.0s
# [CV] END .................max_features=71, n_estimators=1901; total time=  19.2s
# [CV] END .................max_features=71, n_estimators=1851; total time=  21.9s
# [CV] END .................max_features=71, n_estimators=1901; total time=  19.9s
# [CV] END .................max_features=71, n_estimators=1901; total time=  23.3s
# [CV] END .................max_features=71, n_estimators=1951; total time=  19.8s
# [CV] END .................max_features=71, n_estimators=1951; total time=  21.0s
# [CV] END .................max_features=71, n_estimators=1951; total time=  23.2s
# [CV] END .................max_features=71, n_estimators=2001; total time=  20.5s
# [CV] END .................max_features=71, n_estimators=2001; total time=  21.9s
# [CV] END .................max_features=71, n_estimators=2001; total time=  23.9s
# [CV] END .................max_features=71, n_estimators=2051; total time=  20.9s
# [CV] END .................max_features=71, n_estimators=2051; total time=  22.2s
# [CV] END .................max_features=71, n_estimators=2051; total time=  24.3s
# [CV] END .................max_features=71, n_estimators=2101; total time=  21.7s
# [CV] END .................max_features=71, n_estimators=2101; total time=  22.5s
# [CV] END .................max_features=71, n_estimators=2101; total time=  24.6s
# [CV] END .................max_features=71, n_estimators=2151; total time=  21.9s
# [CV] END .................max_features=71, n_estimators=2151; total time=  23.4s
# [CV] END .................max_features=71, n_estimators=2201; total time=  22.2s
# [CV] END .................max_features=71, n_estimators=2151; total time=  26.1s
# [CV] END .................max_features=71, n_estimators=2201; total time=  23.5s
# [CV] END .................max_features=71, n_estimators=2201; total time=  25.7s
# [CV] END .................max_features=71, n_estimators=2251; total time=  22.4s
# [CV] END .................max_features=71, n_estimators=2251; total time=  24.3s
# [CV] END .................max_features=71, n_estimators=2251; total time=  26.4s
# [CV] END .................max_features=71, n_estimators=2301; total time=  24.0s
# [CV] END .................max_features=71, n_estimators=2301; total time=  25.3s
# [CV] END .................max_features=71, n_estimators=2351; total time=  23.6s
# [CV] END .................max_features=71, n_estimators=2301; total time=  27.0s
# [CV] END .................max_features=71, n_estimators=2351; total time=  25.1s
# [CV] END .................max_features=71, n_estimators=2351; total time=  26.9s
# [CV] END .................max_features=71, n_estimators=2401; total time=  25.0s
# [CV] END .................max_features=71, n_estimators=2401; total time=  26.1s
# [CV] END .................max_features=71, n_estimators=2401; total time=  28.1s
# [CV] END .................max_features=71, n_estimators=2451; total time=  25.4s
# [CV] END .................max_features=71, n_estimators=2451; total time=  26.4s
# [CV] END .................max_features=71, n_estimators=2451; total time=  28.3s
# [CV] END .................max_features=71, n_estimators=2501; total time=  25.2s
# [CV] END .................max_features=71, n_estimators=2501; total time=  27.4s
# [CV] END .................max_features=71, n_estimators=2501; total time=  29.3s
# [CV] END .................max_features=71, n_estimators=2551; total time=  25.3s
# [CV] END .................max_features=71, n_estimators=2551; total time=  27.7s
# [CV] END .................max_features=71, n_estimators=2601; total time=  26.5s
# [CV] END .................max_features=71, n_estimators=2551; total time=  29.5s
# [CV] END .................max_features=71, n_estimators=2601; total time=  29.8s
# [CV] END .................max_features=71, n_estimators=2601; total time=  28.9s
# [CV] END .................max_features=71, n_estimators=2651; total time=  27.2s
# [CV] END .................max_features=71, n_estimators=2651; total time=  29.3s
# [CV] END .................max_features=71, n_estimators=2651; total time=  30.3s
# [CV] END .................max_features=71, n_estimators=2701; total time=  28.4s
# [CV] END .................max_features=71, n_estimators=2701; total time=  30.9s
# [CV] END .................max_features=71, n_estimators=2701; total time=  29.1s
# [CV] END .................max_features=71, n_estimators=2751; total time=  28.7s
# [CV] END .................max_features=71, n_estimators=2751; total time=  29.3s
# [CV] END .................max_features=71, n_estimators=2751; total time=  31.6s
# [CV] END .................max_features=71, n_estimators=2801; total time=  28.8s
# [CV] END .................max_features=71, n_estimators=2801; total time=  30.2s
# [CV] END .................max_features=71, n_estimators=2801; total time=  32.1s
# [CV] END .................max_features=71, n_estimators=2851; total time=  28.5s
# [CV] END .................max_features=71, n_estimators=2851; total time=  30.4s
# [CV] END .................max_features=71, n_estimators=2851; total time=  33.3s
# [CV] END .................max_features=71, n_estimators=2901; total time=  29.8s
# [CV] END .................max_features=71, n_estimators=2901; total time=  31.5s
# [CV] END .................max_features=71, n_estimators=2901; total time=  34.3s
# [CV] END .................max_features=71, n_estimators=2951; total time=  30.1s
# [CV] END .................max_features=71, n_estimators=2951; total time=  34.9s
# [CV] END .................max_features=71, n_estimators=2951; total time=  32.2s
# [CV] END .................max_features=71, n_estimators=3001; total time=  30.0s
# [CV] END .................max_features=71, n_estimators=3001; total time=  33.0s
# [CV] END .................max_features=71, n_estimators=3051; total time=  31.7s
# [CV] END .................max_features=71, n_estimators=3001; total time=  35.5s
# [CV] END .................max_features=71, n_estimators=3051; total time=  32.2s
# [CV] END .................max_features=71, n_estimators=3051; total time=  35.8s
# [CV] END .................max_features=71, n_estimators=3101; total time=  31.5s
# [CV] END .................max_features=71, n_estimators=3101; total time=  33.4s
# [CV] END .................max_features=71, n_estimators=3101; total time=  36.9s
# [CV] END .................max_features=71, n_estimators=3151; total time=  31.9s
# [CV] END .................max_features=71, n_estimators=3151; total time=  33.9s
# [CV] END .................max_features=71, n_estimators=3151; total time=  36.7s
# [CV] END .................max_features=71, n_estimators=3201; total time=  32.4s
# [CV] END .................max_features=71, n_estimators=3201; total time=  35.1s
# [CV] END .................max_features=71, n_estimators=3201; total time=  38.1s
# [CV] END .................max_features=71, n_estimators=3251; total time=  32.4s
# [CV] END .................max_features=71, n_estimators=3251; total time=  35.1s
# [CV] END .................max_features=71, n_estimators=3301; total time=  34.0s
# [CV] END .................max_features=71, n_estimators=3251; total time=  38.1s
# [CV] END .................max_features=71, n_estimators=3301; total time=  35.7s
# [CV] END .................max_features=71, n_estimators=3301; total time=  38.7s
# [CV] END .................max_features=71, n_estimators=3351; total time=  34.4s
# [CV] END .................max_features=71, n_estimators=3351; total time=  36.8s
# [CV] END .................max_features=71, n_estimators=3351; total time=  39.1s
# [CV] END .................max_features=71, n_estimators=3401; total time=  34.3s
# [CV] END .................max_features=71, n_estimators=3401; total time=  37.1s
# [CV] END .................max_features=71, n_estimators=3401; total time=  39.7s
# [CV] END .................max_features=71, n_estimators=3451; total time=  35.2s
# [CV] END .................max_features=71, n_estimators=3451; total time=  37.3s
# [CV] END .................max_features=71, n_estimators=3501; total time=  34.9s
# [CV] END .................max_features=71, n_estimators=3451; total time=  40.9s
# [CV] END .................max_features=71, n_estimators=3501; total time=  37.6s
# [CV] END .................max_features=71, n_estimators=3501; total time=  40.4s
# [CV] END .................max_features=71, n_estimators=3551; total time=  37.1s
# [CV] END .................max_features=71, n_estimators=3551; total time=  41.5s
# [CV] END .................max_features=71, n_estimators=3551; total time=  38.7s
# [CV] END .................max_features=71, n_estimators=3601; total time=  36.3s
# [CV] END .................max_features=71, n_estimators=3601; total time=  39.7s
# [CV] END .................max_features=71, n_estimators=3601; total time=  42.1s
# [CV] END .................max_features=71, n_estimators=3651; total time=  37.0s
# [CV] END .................max_features=71, n_estimators=3651; total time=  39.6s
# [CV] END .................max_features=71, n_estimators=3651; total time=  42.3s
# [CV] END .................max_features=71, n_estimators=3701; total time=  38.2s
# [CV] END .................max_features=71, n_estimators=3701; total time=  40.3s
# [CV] END .................max_features=71, n_estimators=3751; total time=  37.6s
# [CV] END .................max_features=71, n_estimators=3701; total time=  43.5s
# [CV] END .................max_features=71, n_estimators=3751; total time=  43.8s
# [CV] END .................max_features=71, n_estimators=3751; total time=  41.0s
# [CV] END .................max_features=71, n_estimators=3801; total time=  38.3s
# [CV] END .................max_features=71, n_estimators=3801; total time=  41.4s
# [CV] END .................max_features=71, n_estimators=3801; total time=  44.5s
# [CV] END .................max_features=71, n_estimators=3851; total time=  38.7s
# [CV] END .................max_features=71, n_estimators=3851; total time=  42.2s
# [CV] END .................max_features=71, n_estimators=3851; total time=  45.5s
# [CV] END .................max_features=71, n_estimators=3901; total time=  39.8s
# [CV] END .................max_features=71, n_estimators=3901; total time=  45.5s
# [CV] END .................max_features=71, n_estimators=3901; total time=  43.2s
# [CV] END .................max_features=71, n_estimators=3951; total time=  39.7s
# [CV] END .................max_features=71, n_estimators=3951; total time=  42.6s
# [CV] END .................max_features=71, n_estimators=3951; total time=  46.3s
# [CV] END .................max_features=71, n_estimators=4001; total time=  40.9s
# [CV] END .................max_features=71, n_estimators=4001; total time=  43.4s
# [CV] END .................max_features=71, n_estimators=4001; total time=  47.6s
# [CV] END .................max_features=71, n_estimators=4051; total time=  41.0s
# [CV] END .................max_features=71, n_estimators=4051; total time=  43.0s
# [CV] END .................max_features=71, n_estimators=4051; total time=  46.8s
# [CV] END .................max_features=71, n_estimators=4101; total time=  40.9s
# [CV] END .................max_features=71, n_estimators=4101; total time=  45.0s
# [CV] END .................max_features=71, n_estimators=4101; total time=  48.3s
# [CV] END .................max_features=71, n_estimators=4151; total time=  42.0s
# [CV] END .................max_features=71, n_estimators=4151; total time=  46.4s
# [CV] END .................max_features=71, n_estimators=4201; total time=  42.4s
# [CV] END .................max_features=71, n_estimators=4151; total time=  48.8s
# [CV] END .................max_features=71, n_estimators=4201; total time=  46.1s
# [CV] END .................max_features=71, n_estimators=4201; total time=  49.7s
# [CV] END .................max_features=71, n_estimators=4251; total time=  43.5s
# [CV] END .................max_features=71, n_estimators=4251; total time=  46.0s
# [CV] END .................max_features=71, n_estimators=4251; total time=  50.0s
# [CV] END .................max_features=71, n_estimators=4301; total time=  44.0s
# [CV] END .................max_features=71, n_estimators=4301; total time=  47.0s
# [CV] END .................max_features=71, n_estimators=4301; total time=  51.1s
# [CV] END .................max_features=71, n_estimators=4351; total time=  44.2s
# [CV] END .................max_features=71, n_estimators=4351; total time=  45.3s
# [CV] END .................max_features=71, n_estimators=4351; total time=  51.9s
# [CV] END .................max_features=71, n_estimators=4401; total time=  44.4s
# [CV] END .................max_features=71, n_estimators=4401; total time=  47.6s
# [CV] END .................max_features=71, n_estimators=4401; total time=  52.3s
# [CV] END .................max_features=71, n_estimators=4451; total time=  44.8s
# [CV] END .................max_features=71, n_estimators=4451; total time=  47.7s
# [CV] END .................max_features=71, n_estimators=4451; total time=  51.9s
# [CV] END .................max_features=71, n_estimators=4501; total time=  45.6s
# [CV] END .................max_features=71, n_estimators=4501; total time=  48.8s
# [CV] END .................max_features=71, n_estimators=4501; total time=  52.5s
# [CV] END .................max_features=71, n_estimators=4551; total time=  46.4s
# [CV] END .................max_features=71, n_estimators=4551; total time=  49.8s
# [CV] END .................max_features=71, n_estimators=4551; total time=  53.4s
# [CV] END .................max_features=71, n_estimators=4601; total time=  46.1s
# [CV] END .................max_features=71, n_estimators=4651; total time=  47.1s
# [CV] END .................max_features=71, n_estimators=4601; total time=  51.1s
# [CV] END .................max_features=71, n_estimators=4601; total time=  54.4s
# [CV] END .................max_features=71, n_estimators=4651; total time=  50.2s
# [CV] END .................max_features=71, n_estimators=4651; total time=  55.4s
# [CV] END .................max_features=71, n_estimators=4701; total time=  47.9s
# [CV] END .................max_features=71, n_estimators=4701; total time=  50.8s
# [CV] END .................max_features=71, n_estimators=4701; total time=  55.6s
# [CV] END .................max_features=71, n_estimators=4751; total time=  48.6s
# [CV] END .................max_features=71, n_estimators=4751; total time=  52.1s
# [CV] END .................max_features=71, n_estimators=4751; total time=  54.5s
# [CV] END .................max_features=71, n_estimators=4801; total time=  48.2s
# [CV] END .................max_features=71, n_estimators=4801; total time=  49.7s
# [CV] END .................max_features=71, n_estimators=4801; total time=  53.8s
# [CV] END .................max_features=71, n_estimators=4851; total time=  45.9s
# [CV] END .................max_features=71, n_estimators=4851; total time=  46.8s
# [CV] END .................max_features=71, n_estimators=4851; total time=  50.6s
# [CV] END .................max_features=71, n_estimators=4901; total time=  41.8s
# [CV] END .................max_features=71, n_estimators=4901; total time=  41.2s
# [CV] END .................max_features=71, n_estimators=4901; total time=  42.8s
# [CV] END .................max_features=71, n_estimators=4951; total time=  34.4s
# [CV] END .................max_features=71, n_estimators=4951; total time=  33.1s
# [CV] END .................max_features=71, n_estimators=4951; total time=  34.2s
# Best parameters: {'max_features': 25, 'n_estimators': 301}
# ['/Users/Jennie/Desktop/WashU/Rotation_labs/Griffith Lab/Neoantigen ML project/output_python/transform_training_data4python.ipynb/rf_best_params_classweight.pkl']

# %% [markdown]
# ## Train

# %%
from sklearn.ensemble import RandomForestClassifier
import joblib

# Load best parameters from grid search
best_params_classweight = joblib.load(outdir / "rf_best_params_classweight.pkl")

# Train the model with OOB enabled
rf_classweight = RandomForestClassifier(
    class_weight='balanced_subsample',
    oob_score=True,
    random_state=918,
    n_jobs=-1,
    **best_params_classweight
)
rf_classweight.fit(X_train, y_train)

# Save the trained model
joblib.dump(rf_classweight, outdir / "rf_classweight_model.pkl")
#joblib.dump(rf_classweight, project_dir / "output_python" / "model_artifacts" / "rf_model_classweight.pkl")
# Out:
# ['/Users/Jennie/Desktop/WashU/Rotation_labs/Griffith Lab/Neoantigen ML project/output_python/transform_training_data4python.ipynb/rf_classweight_model.pkl']

# %% [markdown]
# ## OOB

# %%
# OOB error
oob_error = 1 - rf_classweight.oob_score_
print(f"OOB Error: {oob_error}")

# OOB predictions and confusion matrix
oob_predictions = rf_classweight.oob_decision_function_[:, 1] > 0.5
oob_predictions_int = oob_predictions.astype(int)
oob_conf_matrix = confusion_matrix(y_train, oob_predictions_int)
print("OOB Confusion Matrix:")
print(oob_conf_matrix)

TN, FP, FN, TP = oob_conf_matrix.ravel()
oob_sensitivity = TP / (TP + FN)
oob_specificity = TN / (TN + FP)
print(f"Sensitivity (Recall or True Positive Rate): {oob_sensitivity}")
print(f"Specificity (True Negative Rate): {oob_specificity}")

# OOB ROC AUC
rf_classweight_oob_roc_auc = roc_auc_score(y_train, rf_classweight.oob_decision_function_[:, 1])
print(f"OOB ROC AUC: {rf_classweight_oob_roc_auc}")

# OOB Confusion Matrix Plot
plt.figure(figsize=(7, 5))
sns.heatmap(oob_conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Predicted Reject', 'Predicted Accept'],
            yticklabels=['Actual Reject', 'Actual Accept'])
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('OOB Confusion Matrix (class_weight RF)')
plt.show()

# OOB ROC Curve
fpr, tpr, _ = roc_curve(y_train, rf_classweight.oob_decision_function_[:, 1])
plt.plot(fpr, tpr, label=f'OOB ROC curve (area = {rf_classweight_oob_roc_auc:.2f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('OOB ROC Curve (class_weight RF)')
plt.legend(loc='best')
plt.show()
# Out:
# OOB Error: 0.1326860841423948
# OOB Confusion Matrix:
# [[677  38]
#  [ 85 127]]
# Sensitivity (Recall or True Positive Rate): 0.5990566037735849
# Specificity (True Negative Rate): 0.9468531468531468
# OOB ROC AUC: 0.9107665918986674

# %% [markdown]
# ## Test set evaluation

# %%
# Predict on test set
rf_classweight_pred = rf_classweight.predict(X_test)
rf_classweight_conf_matrix = confusion_matrix(y_test, rf_classweight_pred)
print("Test Set Confusion Matrix:")
print(rf_classweight_conf_matrix)

rf_classweight_pred_accuracy = accuracy_score(y_test, rf_classweight_pred)
print(f"Test Set Accuracy: {rf_classweight_pred_accuracy}")

TN, FP, FN, TP = [int(x) for x in rf_classweight_conf_matrix.ravel()]
rf_classweight_sensitivity = TP / (TP + FN)
rf_classweight_specificity = TN / (TN + FP)
print(f"Sensitivity (Recall or True Positive Rate): {rf_classweight_sensitivity}")
print(f"Specificity (True Negative Rate): {rf_classweight_specificity}")

rf_classweight_pred_prob = rf_classweight.predict_proba(X_test)[:, 1]
rf_classweight_roc_auc = roc_auc_score(y_test, rf_classweight_pred_prob)
print(f"Test Set ROC AUC: {rf_classweight_roc_auc}")

plt.figure(figsize=(7, 5))
sns.heatmap(rf_classweight_conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Predicted Reject', 'Predicted Accept'],
            yticklabels=['Actual Reject', 'Actual Accept'])
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Test Set Confusion Matrix (class_weight RF)')
plt.show()

fpr, tpr, _ = roc_curve(y_test, rf_classweight_pred_prob)
plt.plot(fpr, tpr, label=f'Test Set ROC curve (area = {rf_classweight_roc_auc:.2f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Test Set ROC Curve (class_weight RF)')
plt.legend(loc='best')
plt.show()
# Out:
# Test Set Confusion Matrix:
# [[221   4]
#  [ 33  52]]
# Test Set Accuracy: 0.8806451612903226
# Sensitivity (Recall or True Positive Rate): 0.611764705882353
# Specificity (True Negative Rate): 0.9822222222222222
# Test Set ROC AUC: 0.9608104575163399

# %% [markdown]
# # RF without down-sampling or weighing for comparison

# %%
rf_default = RandomForestClassifier(
    random_state=918,
    oob_score=True,  # want OOB score
    n_jobs=-1
)

rf_default.fit(X_train, y_train)


# OOB error
oob_error = 1 - rf_default.oob_score_
print(f"OOB Error: {oob_error}")

# OOB predictions and confusion matrix
oob_predictions = rf_default.oob_decision_function_[:, 1] > 0.5
oob_predictions_int = oob_predictions.astype(int)
oob_conf_matrix = confusion_matrix(y_train, oob_predictions_int)
print("OOB Confusion Matrix:")
print(oob_conf_matrix)
# OOB ROC AUC
rf_default_oob_roc_auc = roc_auc_score(y_train, rf_default.oob_decision_function_[:, 1])
print(f"OOB ROC AUC: {rf_default_oob_roc_auc}")


# Predict on test set
rf_default_pred = rf_default.predict(X_test)
rf_default_conf_matrix = confusion_matrix(y_test, rf_default_pred)
print("Test Set Confusion Matrix:")
print(rf_default_conf_matrix)

rf_default_pred_accuracy = accuracy_score(y_test, rf_default_pred)
print(f"Test Set Accuracy: {rf_default_pred_accuracy}")

TN, FP, FN, TP = [int(x) for x in rf_default_conf_matrix.ravel()]
rf_default_sensitivity = TP / (TP + FN)
rf_default_specificity = TN / (TN + FP)
print(f"Sensitivity (Recall or True Positive Rate): {rf_default_sensitivity}")
print(f"Specificity (True Negative Rate): {rf_default_specificity}")

rf_default_pred_prob = rf_default.predict_proba(X_test)[:, 1]
rf_default_roc_auc = roc_auc_score(y_test, rf_default_pred_prob)
print(f"Test Set ROC AUC: {rf_default_roc_auc}")
# Out:
# OOB Error: 0.13807982740021574
# OOB Confusion Matrix:
# [[682  33]
#  [ 95 117]]
# OOB ROC AUC: 0.8900349650349649
# Test Set Confusion Matrix:
# [[221   4]
#  [ 39  46]]
# Test Set Accuracy: 0.8612903225806452
# Sensitivity (Recall or True Positive Rate): 0.5411764705882353
# Specificity (True Negative Rate): 0.9822222222222222
# Test Set ROC AUC: 0.915607843137255

# %% [markdown]
# # Summary

# %%
import pandas as pd

# Fill these with your actual results from the notebook
results = {
    "Model": [
        "Random Forest", 
        "Random Forest with weighting", 
        "Random Forest with down-sampling"
    ],
    "OOB AUC": [
        rf_default_oob_roc_auc,      # from rf_default
        rf_classweight_oob_roc_auc,  # from rf_classweight
        rf_ds_oob_roc_auc      # from BalancedRandomForestClassifier
    ],
    "Test Accuracy": [
        rf_default_pred_accuracy,
        rf_classweight_pred_accuracy,
        rf_ds_pred_accuracy
    ],
    "Test Sensitivity": [
        rf_default_sensitivity,
        rf_classweight_sensitivity,
        rf_ds_sensitivity
    ],
    "Test Specificity": [
        rf_default_specificity,
        rf_classweight_specificity,
        rf_ds_specificity
    ],
    "Test AUC": [
        rf_default_roc_auc,
        rf_classweight_roc_auc,
        rf_ds_roc_auc
    ]
}

summary_df = pd.DataFrame(results)
print(summary_df)
# Out:
#                               Model   OOB AUC  Test Accuracy  \
# 0                     Random Forest  0.890035       0.861290
# 1      Random Forest with weighting  0.910767       0.880645
# 2  Random Forest with down-sampling  0.980291       0.903226
#
#    Test Sensitivity  Test Specificity  Test AUC
# 0          0.541176          0.982222  0.915608
# 1          0.611765          0.982222  0.960810
# 2          0.847059          0.924444  0.955268
